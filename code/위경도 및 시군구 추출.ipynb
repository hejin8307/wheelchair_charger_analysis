# %%
import csv
import pandas as pd
file1 = pd.read_csv("C:/Users/user/Desktop/internship/project/data/location/charging in dongjak.csv", encoding='utf-8')
file1
# Out:
#    연번                    설치장소    시설유형                  지번주소  \
# 0    1     총신대입구역 4호선 1번출구 부근    교통시설   서울특별시 동작구 사당로 736-1
# 1    2        이수역 7호선 9번출구 부근    교통시설   서울특별시 동작구 사당동 144-4
# 2    3  사당역 4호선 환승통로 무인사물함 부근    교통시설  서울특별시 동작구 사당동 588-44
# 3    4   서울시립남부장애인종합복지관 본관 1층   노유자시설    서울특별시 동작구 신대방동 722
# 4    5           상도1동주민센터 1층     행정청사     서울특별시 동작구 상도동 437
# 5    6           총신대학교 종합관 1층  교육연구시설   서울특별시 동작구 사당동 200-1
# 6    7       국립서울현충원 종합민원실 1층    기타시설   서울특별시 동작구 동작동 산41-2
# 7    8   사당역 2호선 지하2층 고객센터 부근    교통시설  서울특별시 동작구 사당동 588-44
# 8    9     동작역 4호선 2층대합실 7번기둥    교통시설     서울특별시 동작구 동작동 326
# 9   10      노량진역 9호선 3-1출구 부근    교통시설  서울특별시 동작구 노량진동 60-11
#
#                     도로명주소  설치연도         위도          경도
# 0     서울특별시 동작구 동작대로 117   2010  37.487496  126.971851
# 1      서울특별시 동작구 사당로 310   2016  37.484951  126.980963
# 2       서울특별시 동작구 동작대로 3   2010  37.476825  126.981583
# 3  서울특별시 동작구 여의대방로20길 33   2018  37.491559  126.916627
# ...

# %%
file1['시군구명'] = '동작구'

emd1 = file1[['위도', '경도', '시군구명']]
emd1
# Out:
#           위도          경도 시군구명
# 0  37.487496  126.971851  동작구
# 1  37.484951  126.980963  동작구
# 2  37.476825  126.981583  동작구
# 3  37.491559  126.916627  동작구
# 4  37.498044  126.953048  동작구
# 5  37.488623  126.966817  동작구
# 6  37.503194  126.969328  동작구
# 7  37.476825  126.981583  동작구
# 8  37.503666  126.977294  동작구
# 9  37.513547  126.940844  동작구

# %%
file2 = pd.read_csv("C:/Users/user/Desktop/internship/project/data/location/charging in eunpyeong.csv", encoding='utf-8')
file2

file2['시군구명'] = '은평구'

emd2 = file2[['위도', '경도', '시군구명']]
emd2
# Out:
#            위도          경도 시군구명
# 0   37.602452  126.929331  은평구
# 1   37.600641  126.926738  은평구
# 2   37.583415  126.893661  은평구
# 3   37.605621  126.907072  은평구
# 4   37.602868  126.925629  은평구
# 5   37.593814  126.913206  은평구
# 6   37.583692  126.909256  은평구
# 7   37.591080  126.913272  은평구
# 8   37.586900  126.909774  은평구
# 9   37.605999  126.922953  은평구
# 10  37.618888  126.920832  은평구
# 11  37.618264  126.932912  은평구
# 12  37.610069  126.929777  은평구
# 13  37.623647  126.916661  은평구
# 14  37.626450  126.927260  은평구
# 15  37.594455  126.923140  은평구
# 16  37.614136  126.920793  은평구
# 17  37.611716  126.910341  은평구
# 18  37.604417  126.915163  은평구
# 19  37.632017  126.930117  은평구
# 20  37.605621  126.907072  은평구

# %%
file3 = pd.read_csv("C:/Users/user/Desktop/internship/project/data/location/charging in dongdaemun.csv", encoding='utf-8')
file3

file3['시군구명'] = '동대문구'

emd3 = file3[['위도', '경도', '시군구명']]
emd3
# Out:
#            위도          경도  시군구명
# 0   37.595363  127.052761  동대문구
# 1   37.574202  127.039833  동대문구
# 2   37.570931  127.030250  동대문구
# 3   37.583084  127.073191  동대문구
# 4   37.589103  127.036286  동대문구
# 5   37.566842  127.052602  동대문구
# 6   37.561971  127.064167  동대문구
# 7   37.578163  127.034687  동대문구
# 8   37.589700  127.058025  동대문구
# 9   37.579293  127.047901  동대문구
# 10  37.570931  127.030250  동대문구
# 11  37.565063  127.066693  동대문구
# 12  37.584388  127.049263  동대문구
# 13  37.577321  127.025293  동대문구

# %%
file4 = pd.read_csv("C:/Users/user/Desktop/internship/project/data/location/charging in seongbuk.csv", encoding='utf-8')
file4

emd4 = file4[['위도', '경도', '시군구명']]
emd4
# Out:
#            위도          경도 시군구명
# 0   37.589366  127.016743  성북구
# 1   37.602059  127.032158  성북구
# 2   37.588374  127.005907  성북구
# 3   37.585331  127.019391  성북구
# 4   37.610493  127.056403  성북구
# 5   37.601925  127.041530  성북구
# 6   37.604554  127.045739  성북구
# 7   37.586978  127.018784  성북구
# 8   37.586912  127.018404  성북구
# 9   37.526829  126.917830  성북구
# 10  37.608892  127.037518  성북구
# 11  37.606600  127.026898  성북구
# 12  37.607082  127.033982  성북구

# %%
file5 = pd.read_csv("C:/Users/user/Desktop/internship/project/data/location/charging in yangcheon.csv", encoding='utf-8')
file5

file5['시군구명'] = '양천구'

emd5 = file5[['위도', '경도', '시군구명']]
emd5
# Out:
#            위도          경도 시군구명
# 0   37.544176  126.866365  양천구
# 1   37.516984  126.876540  양천구
# 2   37.519843  126.869903  양천구
# 3   37.516261  126.837901  양천구
# 4   37.511622  126.850381  양천구
# 5   37.530315  126.871120  양천구
# 6   37.533591  126.829041  양천구
# 7   37.518483  126.854233  양천구
# 8   37.516601  126.863871  양천구
# 9   37.516951  126.866564  양천구
# 10  37.510412  126.858634  양천구
# 11  37.534171  126.826465  양천구

# %%
file6 = pd.read_csv("C:/Users/user/Desktop/internship/project/data/location/charging in dobong.csv", encoding='utf-8')
file6

file6['시군구명'] = '도봉구'

emd6 = file6[['위도', '경도', '시군구명']]
emd6
# Out:
#            위도          경도 시군구명
# 0   37.658021  127.038751  도봉구
# 1   37.667609  127.041965  도봉구
# 2   37.656360  127.038772  도봉구
# 3   37.643186  127.045418  도봉구
# 4   37.666308  127.044409  도봉구
# 5   37.689176  127.046130  도봉구
# 6   37.648758  127.035123  도봉구
# 7   37.653186  127.048114  도봉구
# 8   37.680323  127.045755  도봉구
# 9   37.669390  127.046444  도봉구
# 10  37.669390  127.046444  도봉구
# 11  37.669390  127.046444  도봉구
# 12  37.658880  127.035972  도봉구
# 13  37.676217  127.047654  도봉구
# 14  37.644876  127.030955  도봉구
# 15  37.643186  127.045418  도봉구
# 16  37.678670  127.043357  도봉구
# 17  37.654001  127.038604  도봉구
# 18  37.667609  127.041965  도봉구
# 19  37.682082  127.043551  도봉구
# 20  37.668750  127.043799  도봉구
# 21  37.689176  127.046130  도봉구
# 22  37.669280  127.032581  도봉구
# 23  37.670538  127.032176  도봉구
# 24  37.647999  127.026036  도봉구
# 25  37.645857  127.028579  도봉구

# %%
file7 = pd.read_csv("C:/Users/user/Desktop/internship/project/data/location/charging in seoul.csv", encoding='utf-8')
file7

emd7 = file7[['위도', '경도', '시군구명']]

print("pandas version: ", pd.__version__)
pd.set_option('display.max_row', 500)
pd.set_option('display.max_columns', 100)
emd7
# Out:
# pandas version:  1.2.4
#             위도          경도  시군구명
# 0    37.517708  126.915170  영등포구
# 1    37.492830  126.896959  영등포구
# 2    37.515668  126.907666  영등포구
# 3    37.563424  127.036966   성동구
# 4    37.567079  127.033215   성동구
# 5    37.570730  127.034158   성동구
# 6    37.570222  127.033443   성동구
# 7    37.545389  127.047088   성동구
# 8    37.561268  127.038004   성동구
# 9    37.539939  127.053493   성동구
# 10   37.504318  126.896077  영등포구
# 11   37.516806  126.890895  영등포구
# 12   37.533331  126.892916  영등포구
# 13   37.522164  126.919917  영등포구
# 14   37.520858  126.912902  영등포구
# 15   37.516856  126.890558  영등포구
# 16   37.531012  126.897349  영등포구
# 17   37.509493  126.896000  영등포구
# 18   37.517110  126.899523  영등포구
# 19   37.495457  126.905842  영등포구
# 20   37.523646  126.888228  영등포구
# 21   37.536501  126.894039  영등포구
# 22   37.499333  126.909836  영등포구
# 23   37.506392  126.921514  영등포구
# 24   37.593767  126.949691  서대문구
# 25   37.598853  126.947145  서대문구
# ...

# %%
file8 = pd.read_csv("C:/Users/user/Desktop/internship/project/data/location/charging in mapo.csv", encoding='utf-8')
file8

file8['시군구명'] = '마포구'

emd8 = file8[['위도', '경도', '시군구명']]
emd8
# Out:
#            위도          경도 시군구명
# 0   37.562312  126.895105  마포구
# 1   37.573576  126.875285  마포구
# 2   37.563728  126.908853  마포구
# 3   37.543522  126.952745  마포구
# 4   37.562312  126.895105  마포구
# 5   37.543522  126.952745  마포구
# 6   37.544220  126.951740  마포구
# 7   37.549575  126.913991  마포구
# 8   37.550944  126.941002  마포구
# 9   37.565382  126.915147  마포구
# 10  37.563728  126.908853  마포구
# 11  37.553590  126.956739  마포구
# 12  37.543660  126.952570  마포구
# 13  37.569656  126.899058  마포구
# 14  37.555977  126.901282  마포구
# 15  37.547478  126.931855  마포구

# %%
file9 = pd.read_csv("C:/Users/user/Desktop/internship/project/data/location/charging in junggu.csv", encoding='utf-8')
file9

emd9 = file9[['위도', '경도', '시군구명']]
emd9
# Out:
#           위도          경도 시군구명
# 0  37.563758  126.997552   중구
# 1  37.564542  127.015147   중구
# 2  37.568480  127.006050   중구
# 3  37.560997  126.994728   중구
# 4  37.565682  127.008953   중구
# 5  37.565682  127.008953   중구
# 6  37.565145  127.022899   중구
# 7  37.554368  127.009522   중구
# 8  37.559432  126.966133   중구

# %%
file10 = pd.read_csv("C:/Users/user/Desktop/internship/project/data/location/charging in jungnang.csv", encoding='utf-8')
file10

file10.rename(columns={'자치구':'시군구명'}, inplace = True)

emd10 = file10[['위도', '경도', '시군구명']]
emd10
# Out:
#            위도          경도 시군구명
# 0   37.599865  127.092099  중랑구
# 1   37.610768  127.077692  중랑구
# 2   37.589153  127.087341  중랑구
# 3   37.616443  127.093278  중랑구
# 4   37.581788  127.084334  중랑구
# 5   37.596659  127.085265  중랑구
# 6   37.612615  127.103422  중랑구
# 7   37.606586  127.107929  중랑구
# 8   37.573944  127.087076  중랑구
# 9   37.599813  127.082117  중랑구
# 10  37.601757  127.079416  중랑구
# 11  37.619854  127.083202  중랑구
# 12  37.617413  127.083592  중랑구
# 13  37.573781  127.087927  중랑구
# 14  37.606254  127.094152  중랑구
# 15  37.614802  127.087957  중랑구
# 16  37.605262  127.091101  중랑구
# 17  37.587482  127.101898  중랑구
# 18  37.604163  127.096064  중랑구
# 19  37.588368  127.077844  중랑구
# 20  37.613036  127.098413  중랑구
# 21  37.600026  127.106862  중랑구
# 22  37.600636  127.101666  중랑구
# 23  37.585745  127.079482  중랑구
# 24  37.618599  127.104588  중랑구
# 25  37.606305  127.093152  중랑구
# 26  37.592733  127.072429  중랑구
# 27  37.595758  127.082496  중랑구

# %%
result = pd.concat([emd1,emd2, emd3, emd4, emd5, emd6, emd7, emd8, emd9, emd10], ignore_index=True)
print("pandas version: ", pd.__version__)
pd.set_option('display.max_row', 600)
pd.set_option('display.max_columns', 100)
result
# Out:
# pandas version:  1.2.4
#             위도          경도  시군구명
# 0    37.487496  126.971851   동작구
# 1    37.484951  126.980963   동작구
# 2    37.476825  126.981583   동작구
# 3    37.491559  126.916627   동작구
# 4    37.498044  126.953048   동작구
# 5    37.488623  126.966817   동작구
# 6    37.503194  126.969328   동작구
# 7    37.476825  126.981583   동작구
# 8    37.503666  126.977294   동작구
# 9    37.513547  126.940844   동작구
# 10   37.602452  126.929331   은평구
# 11   37.600641  126.926738   은평구
# 12   37.583415  126.893661   은평구
# 13   37.605621  126.907072   은평구
# 14   37.602868  126.925629   은평구
# 15   37.593814  126.913206   은평구
# 16   37.583692  126.909256   은평구
# 17   37.591080  126.913272   은평구
# 18   37.586900  126.909774   은평구
# 19   37.605999  126.922953   은평구
# 20   37.618888  126.920832   은평구
# 21   37.618264  126.932912   은평구
# 22   37.610069  126.929777   은평구
# 23   37.623647  126.916661   은평구
# 24   37.626450  126.927260   은평구
# 25   37.594455  126.923140   은평구
# ...

# %%
result.to_csv("C://Users//user//Desktop//internship//project//data//location//서울 급속충전기(위경도,시군구).csv", index = False, encoding = 'utf-8-sig')
