# %%
import csv
import pandas as pd
file1 = pd.read_csv("C:/Users/user/Desktop/internship/project/data/행정동 지도/행정코드(2020.6).csv", encoding='cp949')

file2 = pd.read_csv("C:/Users/user/Desktop/internship/project/data/consume/행정동별 장애인 복지카드 소비데이터(2014~2015).csv", encoding = 'utf-8')

# %%
file1
# Out:
#         행정코드   동이름
# 0    1101053   사직동
# 1    1101054   삼청동
# 2    1101055   부암동
# 3    1101056   평창동
# 4    1101057   무악동
# ..       ...   ...
# 420  1125070  둔촌1동
# 421  1125071  둔촌2동
# 422  1125072  암사1동
# 423  1125073  천호2동
# 424  1125074    길동
#
# [425 rows x 2 columns]

# %%
file2
# Out:
#         code   상대비율  count 행정동 이름
# 0    1101053  0.39%   3232    사직동
# 1    1101054  0.13%   1029    삼청동
# 2    1101055  0.06%    474    부암동
# 3    1101056  0.27%   2180    평창동
# 4    1101057  0.05%    445    무악동
# ..       ...    ...    ...    ...
# 418  1125070  0.01%    110   둔촌1동
# 419  1125071  0.33%   2749   둔촌2동
# 420  1125072  0.22%   1784   암사1동
# 421  1125073  0.60%   4891   천호2동
# 422  1125074  0.59%   4860     길동
#
# [423 rows x 4 columns]

# %%
pd.set_option('display.max_row', 1000)
pd.set_option('display.max_columns', 100)

left_join = pd.merge(file2, file1, left_on = '행정동 이름', right_on = '동이름', how = 'left')
left_join
# Out:
#         code   상대비율  count       행정동 이름     행정코드          동이름
# 0    1101053  0.39%   3232          사직동  1101053          사직동
# 1    1101054  0.13%   1029          삼청동  1101054          삼청동
# 2    1101055  0.06%    474          부암동  1101055          부암동
# 3    1101056  0.27%   2180          평창동  1101056          평창동
# 4    1101057  0.05%    445          무악동  1101057          무악동
# 5    1101058  0.16%   1287          교남동  1101058          교남동
# 6    1101060  0.07%    542          가회동  1101060          가회동
# 7    1101061  1.27%  10441  종로1.2.3.4가동  1101061  종로1.2.3.4가동
# 8    1101063  0.44%   3640      종로5.6가동  1101063      종로5.6가동
# 9    1101064  0.46%   3757          이화동  1101064          이화동
# 10   1101067  0.18%   1444         창신1동  1101067         창신1동
# 11   1101068  0.06%    523         창신2동  1101068         창신2동
# 12   1101069  0.02%    181         창신3동  1101069         창신3동
# 13   1101070  0.06%    496         숭인1동  1101070         숭인1동
# ...

# %%
left_join.isnull().sum()
# Out:
# code      0
# 상대비율      0
# count     0
# 행정동 이름    0
# 행정코드      0
# 동이름       0
# dtype: int64

# %%
left_join['remove'] = (left_join['code'] != left_join['행정코드'])
is_left_join = left_join['remove'] == True
find_difference = left_join[is_left_join]
find_difference
# Out:
#         code   상대비율  count 행정동 이름     행정코드    동이름  remove
# 88   1106085  0.21%   1706  답십리1동  1106091  답십리1동    True
# 270  1117068  0.20%   1639   오류2동  1117073   오류2동    True
# 329  1121068  0.17%   1435    신사동  1123051    신사동    True
# 358  1123051  0.33%   2675    신사동  1121068    신사동    True
# 400  1124070  0.14%   1152    장지동  1124081    장지동    True

# %%
left_join = left_join.drop(index = 329)
consume = left_join.drop(index = 358)
consume
# Out:
#         code   상대비율  count       행정동 이름     행정코드          동이름  remove
# 0    1101053  0.39%   3232          사직동  1101053          사직동   False
# 1    1101054  0.13%   1029          삼청동  1101054          삼청동   False
# 2    1101055  0.06%    474          부암동  1101055          부암동   False
# 3    1101056  0.27%   2180          평창동  1101056          평창동   False
# 4    1101057  0.05%    445          무악동  1101057          무악동   False
# 5    1101058  0.16%   1287          교남동  1101058          교남동   False
# 6    1101060  0.07%    542          가회동  1101060          가회동   False
# 7    1101061  1.27%  10441  종로1.2.3.4가동  1101061  종로1.2.3.4가동   False
# 8    1101063  0.44%   3640      종로5.6가동  1101063      종로5.6가동   False
# 9    1101064  0.46%   3757          이화동  1101064          이화동   False
# 10   1101067  0.18%   1444         창신1동  1101067         창신1동   False
# 11   1101068  0.06%    523         창신2동  1101068         창신2동   False
# ...

# %%
consume['remove'] = (consume['code'] != consume['행정코드'])
is_consume = consume['remove'] == True
find_difference = consume[is_consume]
find_difference
# Out:
#         code   상대비율  count 행정동 이름     행정코드    동이름  remove
# 88   1106085  0.21%   1706  답십리1동  1106091  답십리1동    True
# 270  1117068  0.20%   1639   오류2동  1117073   오류2동    True
# 400  1124070  0.14%   1152    장지동  1124081    장지동    True

# %%
consume = consume.drop(columns=['remove'], axis=1)
consume
# Out:
#         code   상대비율  count       행정동 이름     행정코드          동이름
# 0    1101053  0.39%   3232          사직동  1101053          사직동
# 1    1101054  0.13%   1029          삼청동  1101054          삼청동
# 2    1101055  0.06%    474          부암동  1101055          부암동
# 3    1101056  0.27%   2180          평창동  1101056          평창동
# 4    1101057  0.05%    445          무악동  1101057          무악동
# 5    1101058  0.16%   1287          교남동  1101058          교남동
# 6    1101060  0.07%    542          가회동  1101060          가회동
# 7    1101061  1.27%  10441  종로1.2.3.4가동  1101061  종로1.2.3.4가동
# 8    1101063  0.44%   3640      종로5.6가동  1101063      종로5.6가동
# 9    1101064  0.46%   3757          이화동  1101064          이화동
# 10   1101067  0.18%   1444         창신1동  1101067         창신1동
# 11   1101068  0.06%    523         창신2동  1101068         창신2동
# 12   1101069  0.02%    181         창신3동  1101069         창신3동
# 13   1101070  0.06%    496         숭인1동  1101070         숭인1동
# ...

# %%
consume.to_csv("C://Users//user//Desktop//internship//project//data//consume//복지카드 소비(행정동코드).csv", index = False, encoding = 'utf-8-sig')
